# %%
import pandas as pd 
from IPython.display import HTML

# %%
data= pd.read_csv("Images_Data/Output/city_data.csv")

# %%
data.head()
# Out:
#             City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0      archidona  37.10   -4.39    288.71        83           0        0.89
# 1   batemans bay -35.72  150.18    287.59        93         100        1.34
# 2       sankheda  22.17   73.58    298.15        65           5        1.50
# 3       hermanus -34.42   19.23    288.71        85          56        4.62
# 4  leningradskiy  69.38  178.42    268.49        91           0        4.42
#
#   Country        Date
# 0      ES  1603596520
# 1      AU  1603596520
# 2      IN  1603596520
# 3      ZA  1603596420
# 4      RU  1603596418

# %%
result = data.to_html() 
print(result)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>City</th>
#       <th>Lat</th>
#       <th>Lng</th>
#       <th>Max Temp</th>
#       <th>Humidity</th>
#       <th>Cloudiness</th>
#       <th>Wind Speed</th>
#       <th>Country</th>
#       <th>Date</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>archidona</td>
#       <td>37.10</td>
#       <td>-4.39</td>
#       <td>288.71</td>
#       <td>83</td>
#       <td>0</td>
#       <td>0.89</td>
#       <td>ES</td>
#       <td>1603596520</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>batemans bay</td>
#       <td>-35.72</td>
#       <td>150.18</td>
#       <td>287.59</td>
#       <td>93</td>
#       <td>100</td>
#       <td>1.34</td>
#       <td>AU</td>
#       <td>1603596520</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>sankheda</td>
#       <td>22.17</td>
#       <td>73.58</td>
#       <td>298.15</td>
# ...
